# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiapfm21/Python_Bootcamp/blob/assignment-3/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 3 Exercises
# ## Control flow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### 1. Write a conditional that prints different messages if a bank account balance is below 3,000, between 3,000 and 10,000, or over 10,000.

# %%
balance = 7500
if balance < 3000:
  print ("Your bank account balance is below $3,000. Consider adding funds.")
elif 3000 <= balance <= 10000:
  print ("Your bank account balance is between $3,000 and $10,000. You're doing well!")
else:
  print ("Your bank account is over $10,000. Good job! You are rich!")
# Out:
# Your bank account balance is between $3,000 and $10,000. You're doing well!

# %% [markdown]
# #### 2. Create a list, `books`, containing the following items: 'War and Peace', 'Pride and Prejudice', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin'.
#
# Then using slicing or indexing, create the following:
# - An empty list
# - The last item of books
# - List of three items: 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin'.

# %%
# Your code goes here
books=['War and Peace', 'Pride and Prejudice', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']
print (books)
# Out:
# ['War and Peace', 'Pride and Prejudice', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %%
books[0:0]
# Out:
# []

# %%
books [-1]
# Out:
# 'Yevgeniy Onegin'

# %%
books [3:6]
# Out:
# ['Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %% [markdown]
# Using list methods:
#
# - Remove 'Pride and Prejudice' from the list.
# - Insert 'Harry Potter and the Chamber of Secrets' after 'Mockingjay'.

# %%
# Your code goes here
books.remove ('Pride and Prejudice')
print (books)
# Out:
# ['War and Peace', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %%
books.insert (3, 'Harry Potter and the Chamber of Secrets')
print (books)
# Out:
# ['War and Peace', 'Mockingjay', 'Three Musketeers', 'Harry Potter and the Chamber of Secrets', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %% [markdown]
# #### 3. Given the list `people`, sort it by people's first name, last name and age. Store the sorted lists as by_first_name, by_last_name, and by_age, respectively.
#
# people = [('Mark', 'Harrison', 56), ('Ken', 'Wolseley', 23), ('Emily', 'Robinson', 77)]

# %%
#sort the people list by peoples first name last name and age
people = [('Mark', 'Harrison', 56), ('Ken', 'Wolseley', 23), ('Emily', 'Robinson', 77)]
by_first_name = sorted(people, key=lambda person: person [0])
print (f"Sorted by first name: {by_first_name}")
by_last_name= sorted(people, key=lambda person: person [1])
print (f"Sorted by last name: {by_last_name}")
by_age= sorted(people, key=lambda person: person [2])
print (f"Sorted by age: {by_age}")
# Out:
# Sorted by first name: [('Emily', 'Robinson', 77), ('Ken', 'Wolseley', 23), ('Mark', 'Harrison', 56)]
# Sorted by last name: [('Mark', 'Harrison', 56), ('Emily', 'Robinson', 77), ('Ken', 'Wolseley', 23)]
# Sorted by age: [('Ken', 'Wolseley', 23), ('Mark', 'Harrison', 56), ('Emily', 'Robinson', 77)]

# %% [markdown]
# #### 4. Write a function called `dict_intersect` that takes two dictionaries, d1 and d2, as arguments and returns a set that contains only the keys found in both of the original dictionaries.

# %%
def dict_intersect(d1, d2):
    # Get the keys as sets
    keys_d1 = set(d1.keys())
    keys_d2 = set(d2.keys())

    # Find the intersection of the two sets of keys
    common_keys = keys_d1.intersection(keys_d2)

    return common_keys

# %%
d1 = {'a': 1, 'b': 2, 'c': 3}
d2 = {'b': 4, 'c': 5, 'd': 6}

common_keys = dict_intersect(d1, d2)
print(f"Common keys: {common_keys}")
# Out:
# Common keys: {'b', 'c'}

# %%
common_keys = dict_intersect(d1, d2)
print(f"Common keys: {common_keys}")
# Out:
# Common keys: {'b', 'c'}

# %% [markdown]
# ## Reading and Writing

# %% [markdown]
# #### 1. Using `w`, create a file called fruits.txt and write the string "tangerines" to it.

# %%
# Your code goes here

# %% [markdown]
# #### 2. Next, use a to append the string "dragon fruit" to the file on a new line.

# %%
# Your code goes here

# %% [markdown]
# #### 3. Finally, use the `r` mode to read and print the entire file.

# %%
# Your code goes here
